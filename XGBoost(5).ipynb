# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/ICCIT2025/blob/main/XGBoost(5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================================
# STEP 1: IMPORT LIBRARIES AND SETUP
# ============================================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                           f1_score, confusion_matrix, classification_report)
import xgboost as xgb
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings('ignore')

# Set style for better plots
plt.style.use('default')
sns.set_palette("husl")

print("✅ Step 1 Complete: All libraries imported successfully!")
# Out:
# ✅ Step 1 Complete: All libraries imported successfully!

# %%
# ============================================================================
# STEP 2: LOAD THE DATASETS
# ============================================================================

# Load the three CSV files
print("📂 Loading datasets...")

try:
    train_df = pd.read_csv("/content/drive/MyDrive/UpdatedDataset/training.csv")
    val_df = pd.read_csv("/content/drive/MyDrive/UpdatedDataset/validating.csv")
    test_df = pd.read_csv("/content/drive/MyDrive/UpdatedDataset/testing.csv")

    print(f"✅ Training data loaded: {train_df.shape}")
    print(f"✅ Validation data loaded: {val_df.shape}")
    print(f"✅ Test data loaded: {test_df.shape}")

    # Display basic info about the data
    print("\n📊 Dataset Information:")
    print(f"Training set columns: {len(train_df.columns)}")
    print(f"Sample of column names: {list(train_df.columns[:5])}")
    print(f"Production range in training: {train_df['Production (M.Ton)'].min():.2f} - {train_df['Production (M.Ton)'].max():.2f}")

except FileNotFoundError as e:
    print("❌ Error: CSV files not found. Please ensure train.csv, validation.csv, and test.csv are in the current directory.")
    print("Current working directory files should include your CSV files.")

print("\n✅ Step 2 Complete: Data loading finished!")
# Out:
# 📂 Loading datasets...
# ✅ Training data loaded: (4928, 86)
# ✅ Validation data loaded: (1056, 86)
# ✅ Test data loaded: (1056, 86)
#
# 📊 Dataset Information:
# Training set columns: 86
# Sample of column names: ['Production (M.Ton)', 'Area (Acres)', 'Temperature at 2 Meters Range (C)', 'Year', 'soil_temperature_0_to_7cm(C)']
# Production range in training: 0.00 - 544979.50
#
# ✅ Step 2 Complete: Data loading finished!

# %%
# ============================================================================
# STEP 3: CREATE PRODUCTION CATEGORIES (5 LEVELS)
# ============================================================================

def create_production_categories(df, thresholds=None):
    """Create 5 production level categories"""
    df = df.copy()
    production_col = 'Production (M.Ton)'

    # Calculate thresholds based on training data quantiles
    if thresholds is None:
        thresholds = [
            df[production_col].quantile(0.2),   # Very Low: 0-20%
            df[production_col].quantile(0.4),   # Low: 20-40%
            df[production_col].quantile(0.6),   # Medium: 40-60%
            df[production_col].quantile(0.8),   # High: 60-80%
            df[production_col].max()            # Very High: 80-100%
        ]

    # Create categories
    conditions = [
        df[production_col] <= thresholds[0],
        (df[production_col] > thresholds[0]) & (df[production_col] <= thresholds[1]),
        (df[production_col] > thresholds[1]) & (df[production_col] <= thresholds[2]),
        (df[production_col] > thresholds[2]) & (df[production_col] <= thresholds[3]),
        df[production_col] > thresholds[3]
    ]

    class_names = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    df['Production_Category'] = np.select(conditions, class_names, default='Medium')

    return df, thresholds

# Apply categorization
print("🏷️ Creating production categories...")

# Create categories using training data thresholds
train_df_cat, production_thresholds = create_production_categories(train_df)
val_df_cat, _ = create_production_categories(val_df, production_thresholds)
test_df_cat, _ = create_production_categories(test_df, production_thresholds)

# Display category distribution
print("\n📊 Production Category Distribution:")
print("Training set:")
print(train_df_cat['Production_Category'].value_counts())
print("\nValidation set:")
print(val_df_cat['Production_Category'].value_counts())
print("\nTest set:")
print(test_df_cat['Production_Category'].value_counts())

print(f"\n📏 Production thresholds used:")
class_names = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
for i, (name, threshold) in enumerate(zip(class_names, production_thresholds)):
    if i == 0:
        print(f"{name}: ≤ {threshold:.2f}")
    else:
        print(f"{name}: {production_thresholds[i-1]:.2f} < x ≤ {threshold:.2f}")

print("\n✅ Step 3 Complete: Production categories created!")
# Out:
# 🏷️ Creating production categories...
#
# 📊 Production Category Distribution:
# Training set:
# Production_Category
# Very Low     987
# Medium       986
# Very High    986
# High         985
# Low          984
# Name: count, dtype: int64
#
# Validation set:
# Production_Category
# Very Low     225
# Medium       219
# Low          211
# Very High    201
# High         200
# Name: count, dtype: int64
#
# Test set:
# Production_Category
# High         232
# Very Low     222
# Low          207
# Medium       198
# Very High    197
# Name: count, dtype: int64
#
# 📏 Production thresholds used:
# Very Low: ≤ 528.00
# Low: 528.00 < x ≤ 1398.58
# Medium: 1398.58 < x ≤ 2877.40
# High: 2877.40 < x ≤ 6481.76
# Very High: 6481.76 < x ≤ 544979.50
#
# ✅ Step 3 Complete: Production categories created!

# %%
# ============================================================================
# STEP 4: PREPARE FEATURES AND TARGETS
# ============================================================================

def prepare_features_targets(df):
    """Prepare features and target variables"""
    # Select feature columns (exclude production columns)
    feature_cols = [col for col in df.columns if col not in ['Production (M.Ton)', 'Production_Category']]

    X = df[feature_cols].copy()
    y = df['Production_Category'].copy()

    # Handle missing values by filling with mean
    X_filled = X.fillna(X.mean())

    return X_filled, y, feature_cols

print("🔧 Preparing features and targets...")

# Prepare data for all sets
X_train, y_train, feature_names = prepare_features_targets(train_df_cat)
X_val, y_val, _ = prepare_features_targets(val_df_cat)
X_test, y_test, _ = prepare_features_targets(test_df_cat)

# Encode target labels
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

print(f"✅ Features prepared: {X_train.shape[1]} features")
print(f"✅ Feature names stored: {len(feature_names)} features")
print(f"✅ Labels encoded: {len(label_encoder.classes_)} classes")
print(f"Class mapping: {dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))}")

print("\n✅ Step 4 Complete: Features and targets prepared!")
# Out:
# 🔧 Preparing features and targets...
# ✅ Features prepared: 85 features
# ✅ Feature names stored: 85 features
# ✅ Labels encoded: 5 classes
# Class mapping: {'High': 0, 'Low': 1, 'Medium': 2, 'Very High': 3, 'Very Low': 4}
#
# ✅ Step 4 Complete: Features and targets prepared!

# %%
# ============================================================================
# STEP 5: TRAIN XGBOOST MODEL WITH REAL-TIME PROGRESS DISPLAY
# ============================================================================

def train_xgboost_with_realtime_display(X_train, y_train, X_val, y_val, n_epochs=250):
    """Train XGBoost model with real-time progress display"""

    print("🚀 Training model with real-time progress display...")
    print("Training model with history tracking...")

    # Initialize training history storage
    training_history = {
        'epochs': [],
        'train_loss': [],
        'val_loss': [],
        'train_acc': [],
        'val_acc': []
    }

    # Train model iteratively to show progress
    model = None
    best_val_loss = float('inf')
    patience_counter = 0
    early_stopping_rounds = 50

    for epoch in range(1, n_epochs + 1):
        # Create model with current number of estimators
        current_model = XGBClassifier(
            n_estimators=epoch,
            max_depth=6,
            learning_rate=0.1,
            subsample=0.8,
            colsample_bytree=0.8,
            random_state=42,
            eval_metric='mlogloss'
        )

        # Train model
        eval_set = [(X_train, y_train), (X_val, y_val)]
        current_model.fit(
            X_train, y_train,
            eval_set=eval_set,
            verbose=False
        )

        # Make predictions
        train_pred = current_model.predict(X_train)
        val_pred = current_model.predict(X_val)

        # Calculate accuracies
        train_acc = accuracy_score(y_train, train_pred)
        val_acc = accuracy_score(y_val, val_pred)

        # Get losses from evaluation results
        train_loss = current_model.evals_result_['validation_0']['mlogloss'][-1]
        val_loss = current_model.evals_result_['validation_1']['mlogloss'][-1]

        # Store history
        training_history['epochs'].append(epoch)
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_acc'].append(train_acc)
        training_history['val_acc'].append(val_acc)

        # Display progress
        print(f"Epoch {epoch:3d}/{n_epochs} - "
              f"Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}, "
              f"Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # Early stopping logic
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            model = current_model  # Save best model
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= early_stopping_rounds:
            print(f"Early stopping at epoch {epoch}")
            break

    print("Training completed.")

    # Store best iteration info in training history for reference
    training_history['best_iteration'] = len(training_history['epochs'])

    return model, training_history

# Train the model with real-time display
model, training_history = train_xgboost_with_realtime_display(
    X_train.values, y_train_encoded,
    X_val.values, y_val_encoded,
    n_epochs=250
)

print(f"\n✅ Training complete! Best iteration: {training_history.get('best_iteration', 'N/A')}")
print("\n✅ Step 5 Complete: Model training with real-time display finished!")
# Out:
# 🚀 Training model with real-time progress display...
# Training model with history tracking...
# Epoch   1/250 - Train Acc: 0.7415, Val Acc: 0.6941, Train Loss: 1.4935, Val Loss: 1.5012
# Epoch   2/250 - Train Acc: 0.7930, Val Acc: 0.7396, Train Loss: 1.3925, Val Loss: 1.4055
# Epoch   3/250 - Train Acc: 0.8068, Val Acc: 0.7434, Train Loss: 1.3045, Val Loss: 1.3234
# Epoch   4/250 - Train Acc: 0.8058, Val Acc: 0.7500, Train Loss: 1.2349, Val Loss: 1.2568
# Epoch   5/250 - Train Acc: 0.8123, Val Acc: 0.7614, Train Loss: 1.1681, Val Loss: 1.1949
# Epoch   6/250 - Train Acc: 0.8157, Val Acc: 0.7642, Train Loss: 1.1104, Val Loss: 1.1410
# Epoch   7/250 - Train Acc: 0.8180, Val Acc: 0.7661, Train Loss: 1.0506, Val Loss: 1.0856
# Epoch   8/250 - Train Acc: 0.8237, Val Acc: 0.7699, Train Loss: 1.0098, Val Loss: 1.0482
# Epoch   9/250 - Train Acc: 0.8255, Val Acc: 0.7689, Train Loss: 0.9596, Val Loss: 1.0018
# Epoch  10/250 - Train Acc: 0.8330, Val Acc: 0.7708, Train Loss: 0.9282, Val Loss: 0.9738
# Epoch  11/250 - Train Acc: 0.8366, Val Acc: 0.7775, Train Loss: 0.8956, Val Loss: 0.9454
# Epoch  12/250 - Train Acc: 0.8356, Val Acc: 0.7727, Train Loss: 0.8624, Val Loss: 0.9150
# Epoch  13/250 - Train Acc: 0.8389, Val Acc: 0.7775, Train Loss: 0.8358, Val Loss: 0.8908
# Epoch  14/250 - Train Acc: 0.8421, Val Acc: 0.7794, Train Loss: 0.8154, Val Loss: 0.8715
# Epoch  15/250 - Train Acc: 0.8468, Val Acc: 0.7765, Train Loss: 0.7915, Val Loss: 0.8503
# Epoch  16/250 - Train Acc: 0.8484, Val Acc: 0.7850, Train Loss: 0.7648, Val Loss: 0.8249
# Epoch  17/250 - Train Acc: 0.8486, Val Acc: 0.7822, Train Loss: 0.7429, Val Loss: 0.8052
# Epoch  18/250 - Train Acc: 0.8506, Val Acc: 0.7879, Train Loss: 0.7249, Val Loss: 0.7886
# Epoch  19/250 - Train Acc: 0.8537, Val Acc: 0.7898, Train Loss: 0.7032, Val Loss: 0.7689
# Epoch  20/250 - Train Acc: 0.8547, Val Acc: 0.7907, Train Loss: 0.6858, Val Loss: 0.7549
# Epoch  21/250 - Train Acc: 0.8559, Val Acc: 0.7936, Train Loss: 0.6652, Val Loss: 0.7363
# Epoch  22/250 - Train Acc: 0.8582, Val Acc: 0.7917, Train Loss: 0.6532, Val Loss: 0.7264
# Epoch  23/250 - Train Acc: 0.8604, Val Acc: 0.7936, Train Loss: 0.6370, Val Loss: 0.7129
# Epoch  24/250 - Train Acc: 0.8618, Val Acc: 0.7917, Train Loss: 0.6217, Val Loss: 0.7004
# Epoch  25/250 - Train Acc: 0.8626, Val Acc: 0.7917, Train Loss: 0.6095, Val Loss: 0.6910
# Epoch  26/250 - Train Acc: 0.8657, Val Acc: 0.7945, Train Loss: 0.5962, Val Loss: 0.6792
# Epoch  27/250 - Train Acc: 0.8673, Val Acc: 0.7936, Train Loss: 0.5859, Val Loss: 0.6705
# Epoch  28/250 - Train Acc: 0.8689, Val Acc: 0.7936, Train Loss: 0.5743, Val Loss: 0.6605
# Epoch  29/250 - Train Acc: 0.8675, Val Acc: 0.7936, Train Loss: 0.5618, Val Loss: 0.6500
# Epoch  30/250 - Train Acc: 0.8683, Val Acc: 0.7907, Train Loss: 0.5509, Val Loss: 0.6405
# Epoch  31/250 - Train Acc: 0.8707, Val Acc: 0.7917, Train Loss: 0.5418, Val Loss: 0.6329
# Epoch  32/250 - Train Acc: 0.8722, Val Acc: 0.7926, Train Loss: 0.5316, Val Loss: 0.6256
# Epoch  33/250 - Train Acc: 0.8734, Val Acc: 0.7955, Train Loss: 0.5214, Val Loss: 0.6168
# Epoch  34/250 - Train Acc: 0.8742, Val Acc: 0.7936, Train Loss: 0.5143, Val Loss: 0.6116
# Epoch  35/250 - Train Acc: 0.8744, Val Acc: 0.7955, Train Loss: 0.5066, Val Loss: 0.6049
# Epoch  36/250 - Train Acc: 0.8758, Val Acc: 0.7945, Train Loss: 0.4985, Val Loss: 0.5992
# Epoch  37/250 - Train Acc: 0.8774, Val Acc: 0.7955, Train Loss: 0.4896, Val Loss: 0.5919
# Epoch  38/250 - Train Acc: 0.8778, Val Acc: 0.7955, Train Loss: 0.4827, Val Loss: 0.5858
# Epoch  39/250 - Train Acc: 0.8797, Val Acc: 0.7983, Train Loss: 0.4755, Val Loss: 0.5802
# Epoch  40/250 - Train Acc: 0.8803, Val Acc: 0.7973, Train Loss: 0.4684, Val Loss: 0.5745
# Epoch  41/250 - Train Acc: 0.8841, Val Acc: 0.7983, Train Loss: 0.4607, Val Loss: 0.5693
# Epoch  42/250 - Train Acc: 0.8837, Val Acc: 0.7964, Train Loss: 0.4549, Val Loss: 0.5648
# Epoch  43/250 - Train Acc: 0.8841, Val Acc: 0.7973, Train Loss: 0.4503, Val Loss: 0.5612
# Epoch  44/250 - Train Acc: 0.8847, Val Acc: 0.8011, Train Loss: 0.4454, Val Loss: 0.5578
# Epoch  45/250 - Train Acc: 0.8866, Val Acc: 0.8011, Train Loss: 0.4400, Val Loss: 0.5535
# Epoch  46/250 - Train Acc: 0.8870, Val Acc: 0.7992, Train Loss: 0.4339, Val Loss: 0.5489
# Epoch  47/250 - Train Acc: 0.8908, Val Acc: 0.8002, Train Loss: 0.4289, Val Loss: 0.5452
# Epoch  48/250 - Train Acc: 0.8916, Val Acc: 0.8021, Train Loss: 0.4239, Val Loss: 0.5421
# Epoch  49/250 - Train Acc: 0.8943, Val Acc: 0.8021, Train Loss: 0.4182, Val Loss: 0.5376
# Epoch  50/250 - Train Acc: 0.8961, Val Acc: 0.8040, Train Loss: 0.4130, Val Loss: 0.5338
# Epoch  51/250 - Train Acc: 0.8977, Val Acc: 0.8049, Train Loss: 0.4084, Val Loss: 0.5303
# Epoch  52/250 - Train Acc: 0.8979, Val Acc: 0.8059, Train Loss: 0.4043, Val Loss: 0.5274
# Epoch  53/250 - Train Acc: 0.8985, Val Acc: 0.8049, Train Loss: 0.3999, Val Loss: 0.5247
# Epoch  54/250 - Train Acc: 0.9008, Val Acc: 0.8040, Train Loss: 0.3959, Val Loss: 0.5228
# Epoch  55/250 - Train Acc: 0.9004, Val Acc: 0.8030, Train Loss: 0.3916, Val Loss: 0.5197
# Epoch  56/250 - Train Acc: 0.9016, Val Acc: 0.8087, Train Loss: 0.3877, Val Loss: 0.5169
# Epoch  57/250 - Train Acc: 0.9010, Val Acc: 0.8059, Train Loss: 0.3838, Val Loss: 0.5145
# Epoch  58/250 - Train Acc: 0.9024, Val Acc: 0.8049, Train Loss: 0.3792, Val Loss: 0.5115
# Epoch  59/250 - Train Acc: 0.9032, Val Acc: 0.8030, Train Loss: 0.3755, Val Loss: 0.5102
# Epoch  60/250 - Train Acc: 0.9050, Val Acc: 0.8030, Train Loss: 0.3722, Val Loss: 0.5084
# Epoch  61/250 - Train Acc: 0.9062, Val Acc: 0.8040, Train Loss: 0.3684, Val Loss: 0.5059
# Epoch  62/250 - Train Acc: 0.9073, Val Acc: 0.8087, Train Loss: 0.3637, Val Loss: 0.5031
# Epoch  63/250 - Train Acc: 0.9093, Val Acc: 0.8087, Train Loss: 0.3605, Val Loss: 0.5009
# Epoch  64/250 - Train Acc: 0.9091, Val Acc: 0.8068, Train Loss: 0.3576, Val Loss: 0.4985
# Epoch  65/250 - Train Acc: 0.9101, Val Acc: 0.8078, Train Loss: 0.3544, Val Loss: 0.4966
# Epoch  66/250 - Train Acc: 0.9111, Val Acc: 0.8087, Train Loss: 0.3508, Val Loss: 0.4938
# Epoch  67/250 - Train Acc: 0.9125, Val Acc: 0.8087, Train Loss: 0.3483, Val Loss: 0.4923
# Epoch  68/250 - Train Acc: 0.9136, Val Acc: 0.8125, Train Loss: 0.3450, Val Loss: 0.4907
# Epoch  69/250 - Train Acc: 0.9146, Val Acc: 0.8106, Train Loss: 0.3404, Val Loss: 0.4890
# Epoch  70/250 - Train Acc: 0.9152, Val Acc: 0.8134, Train Loss: 0.3370, Val Loss: 0.4880
# Epoch  71/250 - Train Acc: 0.9160, Val Acc: 0.8144, Train Loss: 0.3343, Val Loss: 0.4865
# Epoch  72/250 - Train Acc: 0.9168, Val Acc: 0.8134, Train Loss: 0.3313, Val Loss: 0.4852
# Epoch  73/250 - Train Acc: 0.9180, Val Acc: 0.8134, Train Loss: 0.3287, Val Loss: 0.4838
# Epoch  74/250 - Train Acc: 0.9182, Val Acc: 0.8144, Train Loss: 0.3264, Val Loss: 0.4825
# Epoch  75/250 - Train Acc: 0.9205, Val Acc: 0.8125, Train Loss: 0.3238, Val Loss: 0.4811
# Epoch  76/250 - Train Acc: 0.9217, Val Acc: 0.8163, Train Loss: 0.3216, Val Loss: 0.4798
# Epoch  77/250 - Train Acc: 0.9225, Val Acc: 0.8153, Train Loss: 0.3191, Val Loss: 0.4791
# Epoch  78/250 - Train Acc: 0.9229, Val Acc: 0.8163, Train Loss: 0.3155, Val Loss: 0.4772
# Epoch  79/250 - Train Acc: 0.9235, Val Acc: 0.8163, Train Loss: 0.3126, Val Loss: 0.4768
# Epoch  80/250 - Train Acc: 0.9259, Val Acc: 0.8172, Train Loss: 0.3098, Val Loss: 0.4745
# Epoch  81/250 - Train Acc: 0.9265, Val Acc: 0.8163, Train Loss: 0.3070, Val Loss: 0.4730
# Epoch  82/250 - Train Acc: 0.9284, Val Acc: 0.8182, Train Loss: 0.3046, Val Loss: 0.4718
# Epoch  83/250 - Train Acc: 0.9288, Val Acc: 0.8191, Train Loss: 0.3024, Val Loss: 0.4705
# Epoch  84/250 - Train Acc: 0.9298, Val Acc: 0.8182, Train Loss: 0.3003, Val Loss: 0.4701
# Epoch  85/250 - Train Acc: 0.9306, Val Acc: 0.8210, Train Loss: 0.2977, Val Loss: 0.4686
# Epoch  86/250 - Train Acc: 0.9316, Val Acc: 0.8210, Train Loss: 0.2947, Val Loss: 0.4681
# Epoch  87/250 - Train Acc: 0.9322, Val Acc: 0.8191, Train Loss: 0.2925, Val Loss: 0.4671
# Epoch  88/250 - Train Acc: 0.9332, Val Acc: 0.8191, Train Loss: 0.2897, Val Loss: 0.4656
# Epoch  89/250 - Train Acc: 0.9345, Val Acc: 0.8191, Train Loss: 0.2880, Val Loss: 0.4647
# Epoch  90/250 - Train Acc: 0.9349, Val Acc: 0.8172, Train Loss: 0.2860, Val Loss: 0.4638
# Epoch  91/250 - Train Acc: 0.9345, Val Acc: 0.8191, Train Loss: 0.2841, Val Loss: 0.4633
# Epoch  92/250 - Train Acc: 0.9361, Val Acc: 0.8210, Train Loss: 0.2819, Val Loss: 0.4617
# Epoch  93/250 - Train Acc: 0.9367, Val Acc: 0.8172, Train Loss: 0.2801, Val Loss: 0.4610
# Epoch  94/250 - Train Acc: 0.9373, Val Acc: 0.8191, Train Loss: 0.2780, Val Loss: 0.4605
# Epoch  95/250 - Train Acc: 0.9393, Val Acc: 0.8220, Train Loss: 0.2759, Val Loss: 0.4599
# Epoch  96/250 - Train Acc: 0.9389, Val Acc: 0.8239, Train Loss: 0.2742, Val Loss: 0.4591
# Epoch  97/250 - Train Acc: 0.9391, Val Acc: 0.8239, Train Loss: 0.2720, Val Loss: 0.4587
# Epoch  98/250 - Train Acc: 0.9395, Val Acc: 0.8220, Train Loss: 0.2701, Val Loss: 0.4578
# Epoch  99/250 - Train Acc: 0.9414, Val Acc: 0.8239, Train Loss: 0.2678, Val Loss: 0.4568
# Epoch 100/250 - Train Acc: 0.9418, Val Acc: 0.8229, Train Loss: 0.2652, Val Loss: 0.4556
# Epoch 101/250 - Train Acc: 0.9418, Val Acc: 0.8201, Train Loss: 0.2635, Val Loss: 0.4547
# Epoch 102/250 - Train Acc: 0.9426, Val Acc: 0.8229, Train Loss: 0.2612, Val Loss: 0.4538
# Epoch 103/250 - Train Acc: 0.9432, Val Acc: 0.8210, Train Loss: 0.2595, Val Loss: 0.4535
# Epoch 104/250 - Train Acc: 0.9438, Val Acc: 0.8229, Train Loss: 0.2570, Val Loss: 0.4531
# Epoch 105/250 - Train Acc: 0.9444, Val Acc: 0.8248, Train Loss: 0.2553, Val Loss: 0.4527
# Epoch 106/250 - Train Acc: 0.9448, Val Acc: 0.8258, Train Loss: 0.2537, Val Loss: 0.4523
# Epoch 107/250 - Train Acc: 0.9460, Val Acc: 0.8220, Train Loss: 0.2524, Val Loss: 0.4522
# Epoch 108/250 - Train Acc: 0.9466, Val Acc: 0.8220, Train Loss: 0.2508, Val Loss: 0.4516
# Epoch 109/250 - Train Acc: 0.9474, Val Acc: 0.8210, Train Loss: 0.2488, Val Loss: 0.4515
# Epoch 110/250 - Train Acc: 0.9485, Val Acc: 0.8201, Train Loss: 0.2472, Val Loss: 0.4507
# Epoch 111/250 - Train Acc: 0.9487, Val Acc: 0.8201, Train Loss: 0.2456, Val Loss: 0.4500
# Epoch 112/250 - Train Acc: 0.9501, Val Acc: 0.8229, Train Loss: 0.2442, Val Loss: 0.4494
# Epoch 113/250 - Train Acc: 0.9505, Val Acc: 0.8248, Train Loss: 0.2424, Val Loss: 0.4489
# Epoch 114/250 - Train Acc: 0.9507, Val Acc: 0.8248, Train Loss: 0.2410, Val Loss: 0.4484
# Epoch 115/250 - Train Acc: 0.9521, Val Acc: 0.8229, Train Loss: 0.2394, Val Loss: 0.4479
# Epoch 116/250 - Train Acc: 0.9521, Val Acc: 0.8248, Train Loss: 0.2380, Val Loss: 0.4477
# Epoch 117/250 - Train Acc: 0.9531, Val Acc: 0.8239, Train Loss: 0.2363, Val Loss: 0.4474
# Epoch 118/250 - Train Acc: 0.9533, Val Acc: 0.8239, Train Loss: 0.2349, Val Loss: 0.4465
# Epoch 119/250 - Train Acc: 0.9535, Val Acc: 0.8239, Train Loss: 0.2336, Val Loss: 0.4462
# Epoch 120/250 - Train Acc: 0.9547, Val Acc: 0.8220, Train Loss: 0.2321, Val Loss: 0.4458
# Epoch 121/250 - Train Acc: 0.9550, Val Acc: 0.8210, Train Loss: 0.2310, Val Loss: 0.4455
# Epoch 122/250 - Train Acc: 0.9545, Val Acc: 0.8220, Train Loss: 0.2296, Val Loss: 0.4448
# Epoch 123/250 - Train Acc: 0.9550, Val Acc: 0.8220, Train Loss: 0.2283, Val Loss: 0.4446
# Epoch 124/250 - Train Acc: 0.9558, Val Acc: 0.8210, Train Loss: 0.2271, Val Loss: 0.4440
# Epoch 125/250 - Train Acc: 0.9560, Val Acc: 0.8210, Train Loss: 0.2259, Val Loss: 0.4434
# Epoch 126/250 - Train Acc: 0.9560, Val Acc: 0.8220, Train Loss: 0.2243, Val Loss: 0.4429
# Epoch 127/250 - Train Acc: 0.9570, Val Acc: 0.8210, Train Loss: 0.2233, Val Loss: 0.4424
# Epoch 128/250 - Train Acc: 0.9576, Val Acc: 0.8220, Train Loss: 0.2219, Val Loss: 0.4420
# Epoch 129/250 - Train Acc: 0.9574, Val Acc: 0.8220, Train Loss: 0.2207, Val Loss: 0.4415
# Epoch 130/250 - Train Acc: 0.9582, Val Acc: 0.8191, Train Loss: 0.2192, Val Loss: 0.4413
# Epoch 131/250 - Train Acc: 0.9590, Val Acc: 0.8220, Train Loss: 0.2180, Val Loss: 0.4413
# Epoch 132/250 - Train Acc: 0.9596, Val Acc: 0.8210, Train Loss: 0.2163, Val Loss: 0.4402
# Epoch 133/250 - Train Acc: 0.9610, Val Acc: 0.8220, Train Loss: 0.2145, Val Loss: 0.4398
# Epoch 134/250 - Train Acc: 0.9608, Val Acc: 0.8201, Train Loss: 0.2130, Val Loss: 0.4400
# Epoch 135/250 - Train Acc: 0.9606, Val Acc: 0.8229, Train Loss: 0.2120, Val Loss: 0.4399
# Epoch 136/250 - Train Acc: 0.9610, Val Acc: 0.8210, Train Loss: 0.2110, Val Loss: 0.4397
# Epoch 137/250 - Train Acc: 0.9616, Val Acc: 0.8210, Train Loss: 0.2097, Val Loss: 0.4395
# Epoch 138/250 - Train Acc: 0.9619, Val Acc: 0.8220, Train Loss: 0.2082, Val Loss: 0.4392
# Epoch 139/250 - Train Acc: 0.9621, Val Acc: 0.8239, Train Loss: 0.2067, Val Loss: 0.4392
# Epoch 140/250 - Train Acc: 0.9623, Val Acc: 0.8258, Train Loss: 0.2053, Val Loss: 0.4392
# Epoch 141/250 - Train Acc: 0.9627, Val Acc: 0.8248, Train Loss: 0.2043, Val Loss: 0.4388
# Epoch 142/250 - Train Acc: 0.9627, Val Acc: 0.8258, Train Loss: 0.2035, Val Loss: 0.4380
# Epoch 143/250 - Train Acc: 0.9637, Val Acc: 0.8248, Train Loss: 0.2021, Val Loss: 0.4380
# Epoch 144/250 - Train Acc: 0.9641, Val Acc: 0.8248, Train Loss: 0.2011, Val Loss: 0.4378
# Epoch 145/250 - Train Acc: 0.9649, Val Acc: 0.8239, Train Loss: 0.1998, Val Loss: 0.4376
# Epoch 146/250 - Train Acc: 0.9659, Val Acc: 0.8239, Train Loss: 0.1985, Val Loss: 0.4379
# Epoch 147/250 - Train Acc: 0.9669, Val Acc: 0.8248, Train Loss: 0.1964, Val Loss: 0.4370
# Epoch 148/250 - Train Acc: 0.9669, Val Acc: 0.8248, Train Loss: 0.1950, Val Loss: 0.4369
# Epoch 149/250 - Train Acc: 0.9673, Val Acc: 0.8220, Train Loss: 0.1937, Val Loss: 0.4368
# Epoch 150/250 - Train Acc: 0.9677, Val Acc: 0.8239, Train Loss: 0.1928, Val Loss: 0.4365
# Epoch 151/250 - Train Acc: 0.9681, Val Acc: 0.8239, Train Loss: 0.1919, Val Loss: 0.4357
# Epoch 152/250 - Train Acc: 0.9690, Val Acc: 0.8229, Train Loss: 0.1908, Val Loss: 0.4355
# Epoch 153/250 - Train Acc: 0.9685, Val Acc: 0.8248, Train Loss: 0.1901, Val Loss: 0.4353
# Epoch 154/250 - Train Acc: 0.9694, Val Acc: 0.8248, Train Loss: 0.1891, Val Loss: 0.4355
# Epoch 155/250 - Train Acc: 0.9694, Val Acc: 0.8248, Train Loss: 0.1877, Val Loss: 0.4351
# Epoch 156/250 - Train Acc: 0.9700, Val Acc: 0.8277, Train Loss: 0.1864, Val Loss: 0.4349
# Epoch 157/250 - Train Acc: 0.9710, Val Acc: 0.8258, Train Loss: 0.1851, Val Loss: 0.4349
# Epoch 158/250 - Train Acc: 0.9704, Val Acc: 0.8258, Train Loss: 0.1845, Val Loss: 0.4346
# Epoch 159/250 - Train Acc: 0.9716, Val Acc: 0.8267, Train Loss: 0.1831, Val Loss: 0.4346
# Epoch 160/250 - Train Acc: 0.9718, Val Acc: 0.8267, Train Loss: 0.1820, Val Loss: 0.4348
# Epoch 161/250 - Train Acc: 0.9718, Val Acc: 0.8258, Train Loss: 0.1812, Val Loss: 0.4346
# Epoch 162/250 - Train Acc: 0.9722, Val Acc: 0.8267, Train Loss: 0.1802, Val Loss: 0.4342
# Epoch 163/250 - Train Acc: 0.9726, Val Acc: 0.8286, Train Loss: 0.1792, Val Loss: 0.4341
# Epoch 164/250 - Train Acc: 0.9724, Val Acc: 0.8286, Train Loss: 0.1777, Val Loss: 0.4342
# Epoch 165/250 - Train Acc: 0.9730, Val Acc: 0.8314, Train Loss: 0.1769, Val Loss: 0.4336
# Epoch 166/250 - Train Acc: 0.9734, Val Acc: 0.8314, Train Loss: 0.1760, Val Loss: 0.4330
# Epoch 167/250 - Train Acc: 0.9730, Val Acc: 0.8333, Train Loss: 0.1747, Val Loss: 0.4332
# Epoch 168/250 - Train Acc: 0.9736, Val Acc: 0.8343, Train Loss: 0.1739, Val Loss: 0.4333
# Epoch 169/250 - Train Acc: 0.9738, Val Acc: 0.8362, Train Loss: 0.1728, Val Loss: 0.4332
# Epoch 170/250 - Train Acc: 0.9738, Val Acc: 0.8362, Train Loss: 0.1722, Val Loss: 0.4330
# Epoch 171/250 - Train Acc: 0.9744, Val Acc: 0.8362, Train Loss: 0.1715, Val Loss: 0.4327
# Epoch 172/250 - Train Acc: 0.9744, Val Acc: 0.8362, Train Loss: 0.1705, Val Loss: 0.4328
# Epoch 173/250 - Train Acc: 0.9750, Val Acc: 0.8362, Train Loss: 0.1696, Val Loss: 0.4325
# Epoch 174/250 - Train Acc: 0.9761, Val Acc: 0.8324, Train Loss: 0.1683, Val Loss: 0.4321
# Epoch 175/250 - Train Acc: 0.9763, Val Acc: 0.8333, Train Loss: 0.1675, Val Loss: 0.4318
# Epoch 176/250 - Train Acc: 0.9765, Val Acc: 0.8333, Train Loss: 0.1665, Val Loss: 0.4315
# Epoch 177/250 - Train Acc: 0.9771, Val Acc: 0.8352, Train Loss: 0.1654, Val Loss: 0.4311
# Epoch 178/250 - Train Acc: 0.9771, Val Acc: 0.8362, Train Loss: 0.1646, Val Loss: 0.4313
# Epoch 179/250 - Train Acc: 0.9773, Val Acc: 0.8362, Train Loss: 0.1638, Val Loss: 0.4315
# Epoch 180/250 - Train Acc: 0.9775, Val Acc: 0.8371, Train Loss: 0.1627, Val Loss: 0.4311
# Epoch 181/250 - Train Acc: 0.9777, Val Acc: 0.8343, Train Loss: 0.1619, Val Loss: 0.4312
# Epoch 182/250 - Train Acc: 0.9785, Val Acc: 0.8362, Train Loss: 0.1609, Val Loss: 0.4311
# Epoch 183/250 - Train Acc: 0.9791, Val Acc: 0.8352, Train Loss: 0.1598, Val Loss: 0.4310
# Epoch 184/250 - Train Acc: 0.9795, Val Acc: 0.8343, Train Loss: 0.1589, Val Loss: 0.4319
# Epoch 185/250 - Train Acc: 0.9799, Val Acc: 0.8352, Train Loss: 0.1582, Val Loss: 0.4320
# Epoch 186/250 - Train Acc: 0.9799, Val Acc: 0.8352, Train Loss: 0.1576, Val Loss: 0.4319
# Epoch 187/250 - Train Acc: 0.9797, Val Acc: 0.8343, Train Loss: 0.1565, Val Loss: 0.4327
# Epoch 188/250 - Train Acc: 0.9809, Val Acc: 0.8333, Train Loss: 0.1556, Val Loss: 0.4326
# Epoch 189/250 - Train Acc: 0.9809, Val Acc: 0.8324, Train Loss: 0.1547, Val Loss: 0.4322
# Epoch 190/250 - Train Acc: 0.9807, Val Acc: 0.8333, Train Loss: 0.1539, Val Loss: 0.4320
# Epoch 191/250 - Train Acc: 0.9811, Val Acc: 0.8324, Train Loss: 0.1530, Val Loss: 0.4319
# Epoch 192/250 - Train Acc: 0.9815, Val Acc: 0.8314, Train Loss: 0.1521, Val Loss: 0.4322
# Epoch 193/250 - Train Acc: 0.9815, Val Acc: 0.8324, Train Loss: 0.1511, Val Loss: 0.4325
# Epoch 194/250 - Train Acc: 0.9828, Val Acc: 0.8324, Train Loss: 0.1502, Val Loss: 0.4323
# Epoch 195/250 - Train Acc: 0.9821, Val Acc: 0.8305, Train Loss: 0.1493, Val Loss: 0.4320
# Epoch 196/250 - Train Acc: 0.9819, Val Acc: 0.8305, Train Loss: 0.1487, Val Loss: 0.4322
# Epoch 197/250 - Train Acc: 0.9834, Val Acc: 0.8305, Train Loss: 0.1477, Val Loss: 0.4326
# Epoch 198/250 - Train Acc: 0.9838, Val Acc: 0.8314, Train Loss: 0.1470, Val Loss: 0.4326
# Epoch 199/250 - Train Acc: 0.9838, Val Acc: 0.8333, Train Loss: 0.1463, Val Loss: 0.4329
# Epoch 200/250 - Train Acc: 0.9838, Val Acc: 0.8352, Train Loss: 0.1455, Val Loss: 0.4329
# Epoch 201/250 - Train Acc: 0.9836, Val Acc: 0.8362, Train Loss: 0.1449, Val Loss: 0.4333
# Epoch 202/250 - Train Acc: 0.9840, Val Acc: 0.8343, Train Loss: 0.1442, Val Loss: 0.4331
# Epoch 203/250 - Train Acc: 0.9840, Val Acc: 0.8333, Train Loss: 0.1435, Val Loss: 0.4333
# Epoch 204/250 - Train Acc: 0.9848, Val Acc: 0.8352, Train Loss: 0.1425, Val Loss: 0.4330
# Epoch 205/250 - Train Acc: 0.9852, Val Acc: 0.8333, Train Loss: 0.1416, Val Loss: 0.4325
# Epoch 206/250 - Train Acc: 0.9856, Val Acc: 0.8333, Train Loss: 0.1409, Val Loss: 0.4324
# Epoch 207/250 - Train Acc: 0.9856, Val Acc: 0.8314, Train Loss: 0.1401, Val Loss: 0.4324
# Epoch 208/250 - Train Acc: 0.9862, Val Acc: 0.8314, Train Loss: 0.1394, Val Loss: 0.4322
# Epoch 209/250 - Train Acc: 0.9862, Val Acc: 0.8324, Train Loss: 0.1384, Val Loss: 0.4326
# Epoch 210/250 - Train Acc: 0.9860, Val Acc: 0.8295, Train Loss: 0.1374, Val Loss: 0.4331
# Epoch 211/250 - Train Acc: 0.9866, Val Acc: 0.8305, Train Loss: 0.1366, Val Loss: 0.4326
# Epoch 212/250 - Train Acc: 0.9868, Val Acc: 0.8305, Train Loss: 0.1358, Val Loss: 0.4321
# Epoch 213/250 - Train Acc: 0.9874, Val Acc: 0.8305, Train Loss: 0.1348, Val Loss: 0.4320
# Epoch 214/250 - Train Acc: 0.9880, Val Acc: 0.8295, Train Loss: 0.1342, Val Loss: 0.4322
# Epoch 215/250 - Train Acc: 0.9880, Val Acc: 0.8305, Train Loss: 0.1334, Val Loss: 0.4323
# Epoch 216/250 - Train Acc: 0.9884, Val Acc: 0.8314, Train Loss: 0.1327, Val Loss: 0.4324
# Epoch 217/250 - Train Acc: 0.9886, Val Acc: 0.8305, Train Loss: 0.1320, Val Loss: 0.4324
# Epoch 218/250 - Train Acc: 0.9886, Val Acc: 0.8295, Train Loss: 0.1315, Val Loss: 0.4321
# Epoch 219/250 - Train Acc: 0.9890, Val Acc: 0.8305, Train Loss: 0.1307, Val Loss: 0.4321
# Epoch 220/250 - Train Acc: 0.9894, Val Acc: 0.8314, Train Loss: 0.1300, Val Loss: 0.4324
# Epoch 221/250 - Train Acc: 0.9894, Val Acc: 0.8314, Train Loss: 0.1294, Val Loss: 0.4326
# Epoch 222/250 - Train Acc: 0.9897, Val Acc: 0.8314, Train Loss: 0.1287, Val Loss: 0.4326
# Epoch 223/250 - Train Acc: 0.9894, Val Acc: 0.8295, Train Loss: 0.1280, Val Loss: 0.4328
# Epoch 224/250 - Train Acc: 0.9894, Val Acc: 0.8286, Train Loss: 0.1273, Val Loss: 0.4331
# Epoch 225/250 - Train Acc: 0.9894, Val Acc: 0.8314, Train Loss: 0.1268, Val Loss: 0.4329
# Epoch 226/250 - Train Acc: 0.9899, Val Acc: 0.8305, Train Loss: 0.1262, Val Loss: 0.4326
# Epoch 227/250 - Train Acc: 0.9903, Val Acc: 0.8314, Train Loss: 0.1253, Val Loss: 0.4319
# Epoch 228/250 - Train Acc: 0.9907, Val Acc: 0.8295, Train Loss: 0.1243, Val Loss: 0.4315
# Epoch 229/250 - Train Acc: 0.9909, Val Acc: 0.8295, Train Loss: 0.1237, Val Loss: 0.4315
# Epoch 230/250 - Train Acc: 0.9907, Val Acc: 0.8277, Train Loss: 0.1231, Val Loss: 0.4314
# Epoch 231/250 - Train Acc: 0.9907, Val Acc: 0.8286, Train Loss: 0.1224, Val Loss: 0.4323
# Epoch 232/250 - Train Acc: 0.9909, Val Acc: 0.8286, Train Loss: 0.1217, Val Loss: 0.4323
# Epoch 233/250 - Train Acc: 0.9911, Val Acc: 0.8305, Train Loss: 0.1211, Val Loss: 0.4326
# Early stopping at epoch 233
# Training completed.
#
# ✅ Training complete! Best iteration: 233
#
# ✅ Step 5 Complete: Model training with real-time display finished!

# %%
# ============================================================================
# STEP 6: PLOT TRAINING PROGRESS ANALYSIS
# ============================================================================

def plot_training_progress_analysis(training_history):
    """Plot training progress with loss and accuracy curves"""

    # Set up the figure with subplots
    fig = plt.figure(figsize=(16, 6))

    # Add main title
    fig.suptitle('Training Progress Analysis', fontsize=16, fontweight='bold', y=0.98)

    # Create subplots
    ax1 = plt.subplot(1, 2, 1)  # Loss plot
    ax2 = plt.subplot(1, 2, 2)  # Accuracy plot

    # Plot 1: Model Loss Over Training
    ax1.plot(training_history['epochs'], training_history['train_loss'],
             'b-', linewidth=2.5, label='Training Loss')
    ax1.plot(training_history['epochs'], training_history['val_loss'],
             'r-', linewidth=2.5, label='Validation Loss')

    ax1.set_title('Model Loss Over Training', fontsize=14, fontweight='bold', pad=15)
    ax1.set_xlabel('Iteration', fontsize=12)
    ax1.set_ylabel('Multi-class Log Loss', fontsize=12)
    ax1.legend(fontsize=11, loc='upper right')
    ax1.grid(True, alpha=0.3)
    ax1.set_xlim(0, max(training_history['epochs']))

    # Plot 2: Model Accuracy Over Training
    ax2.plot(training_history['epochs'], training_history['train_acc'],
             'b-', linewidth=2.5, label='Training Accuracy')
    ax2.plot(training_history['epochs'], training_history['val_acc'],
             'orange', linewidth=2.5, label='Validation Accuracy')

    ax2.set_title('Model Accuracy Over Training', fontsize=14, fontweight='bold', pad=15)
    ax2.set_xlabel('Iteration', fontsize=12)
    ax2.set_ylabel('Accuracy', fontsize=12)
    ax2.legend(fontsize=11, loc='lower right')
    ax2.grid(True, alpha=0.3)
    ax2.set_xlim(0, max(training_history['epochs']))
    ax2.set_ylim(0, 1)

    # Adjust layout
    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()

    # Print training progress summary
    print(f"\n📊 Training Progress Summary:")
    print(f"- Total epochs trained: {len(training_history['epochs'])}")
    print(f"- Final training loss: {training_history['train_loss'][-1]:.4f}")
    print(f"- Final validation loss: {training_history['val_loss'][-1]:.4f}")
    print(f"- Final training accuracy: {training_history['train_acc'][-1]:.4f}")
    print(f"- Final validation accuracy: {training_history['val_acc'][-1]:.4f}")
    print(f"- Best iteration (early stopping): {training_history.get('best_iteration', 'N/A')}")

print("📈 Generating training progress visualizations...")
plot_training_progress_analysis(training_history)

print("\n✅ Step 6 Complete: Training progress analysis plotted!")
# Out:
# 📈 Generating training progress visualizations...
# 📊 Training Progress Summary:
# - Total epochs trained: 233
# - Final training loss: 0.1211
# - Final validation loss: 0.4326
# - Final training accuracy: 0.9911
# - Final validation accuracy: 0.8305
# - Best iteration (early stopping): 233
#
# ✅ Step 6 Complete: Training progress analysis plotted!

# %%
# ============================================================================
# STEP 7: EVALUATE MODEL AND CALCULATE ALL METRICS
# ============================================================================

def calculate_all_metrics(model, X, y, dataset_name):
    """Calculate comprehensive metrics"""
    y_pred = model.predict(X)

    # Calculate all required metrics
    accuracy = accuracy_score(y, y_pred)
    precision = precision_score(y, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y, y_pred, average='weighted', zero_division=0)
    f1_weighted = f1_score(y, y_pred, average='weighted', zero_division=0)
    f1_macro = f1_score(y, y_pred, average='macro', zero_division=0)

    metrics = {
        'Dataset': dataset_name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score (Weighted Avg)': f1_weighted,
        'Macro F1 Score': f1_macro
    }

    return metrics, y_pred

print("📊 Evaluating model on all datasets...")

# Evaluate on training set
train_metrics, train_pred = calculate_all_metrics(model, X_train.values, y_train_encoded, "Training")

# Evaluate on validation set
val_metrics, val_pred = calculate_all_metrics(model, X_val.values, y_val_encoded, "Validation")

# Evaluate on test set
test_metrics, test_pred = calculate_all_metrics(model, X_test.values, y_test_encoded, "Test")

# Create results summary
results_df = pd.DataFrame([train_metrics, val_metrics, test_metrics])

print("\n🎯 MODEL EVALUATION RESULTS:")
print("="*80)
print(results_df.round(4).to_string(index=False))
print("="*80)

print("\n✅ Step 7 Complete: Model evaluation finished!")
# Out:
# 📊 Evaluating model on all datasets...
#
# 🎯 MODEL EVALUATION RESULTS:
# ================================================================================
#    Dataset  Accuracy  Precision  Recall  F1 Score (Weighted Avg)  Macro F1 Score
#   Training    0.9791     0.9792  0.9791                   0.9791          0.9791
# Validation    0.8352     0.8350  0.8352                   0.8350          0.8339
#       Test    0.8438     0.8462  0.8438                   0.8441          0.8436
# ================================================================================
#
# ✅ Step 7 Complete: Model evaluation finished!

# %%
# ============================================================================
# STEP 8: PLOT CONFUSION MATRICES
# ============================================================================

def plot_confusion_matrix(y_true, y_pred, dataset_name, class_names):
    """Plot confusion matrix"""
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
               xticklabels=class_names,
               yticklabels=class_names,
               cbar_kws={'label': 'Number of Samples'})

    plt.title(f'Confusion Matrix - {dataset_name}', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')
    plt.ylabel('True Label', fontsize=12, fontweight='bold')

    # Add accuracy to the plot
    accuracy = accuracy_score(y_true, y_pred)
    plt.text(0.02, 0.98, f'Accuracy: {accuracy:.3f}',
             transform=plt.gca().transAxes, fontsize=8,
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

    plt.tight_layout()
    plt.show()

print("📈 Plotting confusion matrices...")

class_names = ['Very Low', 'Low', 'Medium', 'High', 'Very High']

# Plot confusion matrix for validation set
plot_confusion_matrix(y_val_encoded, val_pred, "Validation Set", class_names)

# Plot confusion matrix for test set
plot_confusion_matrix(y_test_encoded, test_pred, "Test Set", class_names)

print("\n✅ Step 8 Complete: Confusion matrices plotted!")
# Out:
# 📈 Plotting confusion matrices...
# ✅ Step 8 Complete: Confusion matrices plotted!

# %%
# ============================================================================
# STEP 9: DETAILED CLASSIFICATION REPORTS
# ============================================================================

print("📋 Generating detailed classification reports...")

print("\n" + "="*60)
print("DETAILED CLASSIFICATION REPORT - VALIDATION SET")
print("="*60)
val_report = classification_report(
    y_val_encoded, val_pred,
    target_names=class_names,
    zero_division=0
)
print(val_report)

print("\n" + "="*60)
print("DETAILED CLASSIFICATION REPORT - TEST SET")
print("="*60)
test_report = classification_report(
    y_test_encoded, test_pred,
    target_names=class_names,
    zero_division=0
)
print(test_report)

print("\n✅ Step 9 Complete: Classification reports generated!")
# Out:
# 📋 Generating detailed classification reports...
#
# ============================================================
# DETAILED CLASSIFICATION REPORT - VALIDATION SET
# ============================================================
#               precision    recall  f1-score   support
#
#     Very Low       0.75      0.75      0.75       200
#          Low       0.81      0.83      0.82       211
#       Medium       0.78      0.75      0.77       219
#         High       0.90      0.90      0.90       201
#    Very High       0.93      0.93      0.93       225
#
#     accuracy                           0.84      1056
#    macro avg       0.83      0.83      0.83      1056
# weighted avg       0.83      0.84      0.83      1056
#
#
# ============================================================
# DETAILED CLASSIFICATION REPORT - TEST SET
# ============================================================
#               precision    recall  f1-score   support
#
#     Very Low       0.75      0.83      0.79       232
#          Low       0.84      0.86      0.85       207
#       Medium       0.80      0.73      0.76       198
#         High       0.89      0.85      0.87       197
#    Very High       0.95      0.94      0.95       222
#
#     accuracy                           0.84      1056
#    macro avg       0.85      0.84      0.84      1056
# weighted avg       0.85      0.84      0.84      1056
#
#
# ✅ Step 9 Complete: Classification reports generated!

# %%
# ============================================================================
# STEP 10: FEATURE IMPORTANCE ANALYSIS
# ============================================================================

def plot_feature_importance(model, feature_names, top_n=20):
    """Plot top N most important features"""

    # Get feature importance
    importance = model.feature_importances_

    # Get top N features
    indices = np.argsort(importance)[::-1][:top_n]
    top_features = [feature_names[i] for i in indices]
    top_importance = importance[indices]

    # Create plot
    plt.figure(figsize=(12, 8))
    colors = plt.cm.viridis(np.linspace(0, 1, len(top_importance)))

    bars = plt.barh(range(len(top_importance)), top_importance[::-1], color=colors[::-1])
    plt.yticks(range(len(top_importance)), top_features[::-1])
    plt.xlabel('Importance Score', fontsize=12, fontweight='bold')
    plt.title(f'Top {top_n} Most Important Features', fontsize=16, fontweight='bold', pad=20)

    # Add value labels on bars
    for i, (bar, val) in enumerate(zip(bars, top_importance[::-1])):
        plt.text(val + 0.001, bar.get_y() + bar.get_height()/2,
                f'{val:.3f}', ha='left', va='center', fontsize=9)

    plt.tight_layout()
    plt.show()

    # Print top 10 features
    print(f"\n🏆 Top 10 Most Important Features:")
    for i, (feature, score) in enumerate(zip(top_features[:10], top_importance[:10])):
        print(f"{i+1:2d}. {feature:<40} {score:.4f}")

print("📊 Analyzing feature importance...")
plot_feature_importance(model, feature_names, top_n=20)

print("\n✅ Step 10 Complete: Feature importance analysis finished!")
# Out:
# 📊 Analyzing feature importance...
# 🏆 Top 10 Most Important Features:
#  1. Area (Acres)                             0.0527
#  2. Crop_Laushak                             0.0354
#  3. District_Patuakhali                      0.0345
#  4. District_Barguna                         0.0286
#  5. Crop_Bengal Spinach                      0.0265
#  6. Crop_Garlic                              0.0230
#  7. Crop_Cabbage                             0.0210
#  8. Crop_Beans                               0.0202
#  9. District_Bhola                           0.0195
# 10. Crop_Onion                               0.0191
#
# ✅ Step 10 Complete: Feature importance analysis finished!

# %%
# ============================================================================
# STEP 11: FINAL SUMMARY AND KEY INSIGHTS
# ============================================================================

print("\n" + "="*80)
print("🎉 FINAL SUMMARY - XGBOOST CLASSIFICATION RESULTS")
print("="*80)

print("\n📊 PERFORMANCE METRICS SUMMARY:")
print("-" * 50)
for _, row in results_df.iterrows():
    print(f"{row['Dataset']:12} | Accuracy: {row['Accuracy']:.4f} | Macro F1: {row['Macro F1 Score']:.4f}")

print(f"\n🎯 KEY INSIGHTS:")
print(f"- Best performing dataset: {results_df.loc[results_df['Accuracy'].idxmax(), 'Dataset']}")
print(f"- Highest Macro F1 Score: {results_df['Macro F1 Score'].max():.4f}")
print(f"- Model converged at epoch: {training_history.get('best_iteration', len(training_history['epochs']))}")
print(f"- Total features used: {len(feature_names)}")
print(f"- Classes predicted: {len(class_names)}")

print(f"\n💡 RECOMMENDATIONS:")
if results_df.loc[2, 'Accuracy'] > 0.8:  # Test set accuracy
    print("✅ Model shows good performance on test data")
else:
    print("⚠️  Consider hyperparameter tuning or feature engineering")

if abs(results_df.loc[0, 'Accuracy'] - results_df.loc[1, 'Accuracy']) > 0.1:  # Train vs Val
    print("⚠️  Possible overfitting detected - consider regularization")
else:
    print("✅ Good generalization between training and validation")

print("\n🔧 MODEL CONFIGURATION USED:")
print("- Algorithm: XGBoost Classifier")
print("- Max Depth: 6")
print("- Learning Rate: 0.1")
print("- Subsample: 0.8")
print("- Column Sample: 0.8")
print("- Early Stopping: 50 rounds")
print("- Max Epochs: 250")

print("\n" + "="*80)
print("✅ ALL STEPS COMPLETED SUCCESSFULLY!")
print(" XGBoost classification model is ready for production use!")
print("="*80)
# Out:
# ================================================================================
# 🎉 FINAL SUMMARY - XGBOOST CLASSIFICATION RESULTS
# ================================================================================
#
# 📊 PERFORMANCE METRICS SUMMARY:
# --------------------------------------------------
# Training     | Accuracy: 0.9791 | Macro F1: 0.9791
# Validation   | Accuracy: 0.8352 | Macro F1: 0.8339
# Test         | Accuracy: 0.8438 | Macro F1: 0.8436
#
# 🎯 KEY INSIGHTS:
# - Best performing dataset: Training
# - Highest Macro F1 Score: 0.9791
# - Model converged at epoch: 233
# - Total features used: 85
# - Classes predicted: 5
#
# 💡 RECOMMENDATIONS:
# ✅ Model shows good performance on test data
# ⚠️  Possible overfitting detected - consider regularization
#
# 🔧 MODEL CONFIGURATION USED:
# - Algorithm: XGBoost Classifier
# - Max Depth: 6
# - Learning Rate: 0.1
# - Subsample: 0.8
# - Column Sample: 0.8
# - Early Stopping: 50 rounds
# - Max Epochs: 250
#
# ================================================================================
# ✅ ALL STEPS COMPLETED SUCCESSFULLY!
#  XGBoost classification model is ready for production use!
# ================================================================================
