# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/ICCIT2025/blob/main/AUTOINT(6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# AutoInt Model for Agricultural Production Classification
# Modified for 6 production labels: Very Low, Low, Medium, High, Very High, Extremely High
# Each block shows its functionality and can be executed independently

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Embedding, Flatten, Concatenate, Layer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import warnings
warnings.filterwarnings('ignore')

# %%
# ============================================================================
# BLOCK 1: DEFINE AUTOINT ARCHITECTURE
# Functionality: Creates the AutoInt layer with self-attention mechanism
# ============================================================================
print("BLOCK 1: Defining AutoInt Architecture")
print("=" * 50)

class AutoIntLayer(Layer):
    """
    AutoInt layer implementing self-attention mechanism for feature interactions
    """
    def __init__(self, embed_dim, num_heads=8, **kwargs):
        super(AutoIntLayer, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.attention = tf.keras.layers.MultiHeadAttention(
            num_heads=num_heads,
            key_dim=embed_dim//num_heads,
            dropout=0.1
        )
        self.norm = tf.keras.layers.LayerNormalization()

    def call(self, inputs):
        # Self-attention
        attention_output = self.attention(inputs, inputs)
        # Add & Norm
        output = self.norm(inputs + attention_output)
        return output

    def get_config(self):
        config = super().get_config()
        config.update({
            'embed_dim': self.embed_dim,
            'num_heads': self.num_heads
        })
        return config

print("✓ AutoInt layer architecture defined successfully")
print("✓ Multi-head attention mechanism ready")
print("✓ Layer normalization included")
# Out:
# BLOCK 1: Defining AutoInt Architecture
# ==================================================
# ✓ AutoInt layer architecture defined successfully
# ✓ Multi-head attention mechanism ready
# ✓ Layer normalization included

# %%
# ============================================================================
# BLOCK 2: LOAD AND EXAMINE DATASETS
# Functionality: Loads train.csv, validation.csv, test.csv and shows basic info
# ============================================================================
print("\nBLOCK 2: Loading and Examining Datasets")
print("=" * 50)

# Load datasets
train_df = pd.read_csv('/content/drive/MyDrive/UpdatedDataset/training.csv')
val_df = pd.read_csv('/content/drive/MyDrive/UpdatedDataset/validating.csv')
test_df = pd.read_csv('/content/drive/MyDrive/UpdatedDataset/testing.csv')

print(f"✓ Training data loaded: {train_df.shape}")
print(f"✓ Validation data loaded: {val_df.shape}")
print(f"✓ Test data loaded: {test_df.shape}")

# Show production statistics
print(f"\nProduction (M.Ton) statistics from training data:")
print(train_df['Production (M.Ton)'].describe())

print(f"\nDataset columns: {len(train_df.columns)}")
print(f"Sample columns: {list(train_df.columns[:10])}")
# Out:
# BLOCK 2: Loading and Examining Datasets
# ==================================================
# ✓ Training data loaded: (4928, 86)
# ✓ Validation data loaded: (1056, 86)
# ✓ Test data loaded: (1056, 86)
#
# Production (M.Ton) statistics from training data:
# count      4928.000000
# mean       6860.386686
# std       27733.917777
# min           0.000000
# 25%         690.000000
# 50%        2027.000000
# 75%        5188.250000
# max      544979.500000
# Name: Production (M.Ton), dtype: float64
#
# Dataset columns: 86
# Sample columns: ['Production (M.Ton)', 'Area (Acres)', 'Temperature at 2 Meters Range (C)', 'Year', 'soil_temperature_0_to_7cm(C)', 'Root Zone Soil Wetness (surface to 100 cm below)', 'soil_moisture_0_to_7cm(mÂ³/mÂ³)', 'Surface Soil Wetness (surface to 5 cm below)', 'soil_moiture_7_to_28cm(mÂ³/mÂ³)', 'total_rain_mm']

# %%
# ============================================================================
# BLOCK 3: CREATE QUANTILE-BASED LABELS (6 CLASSES)
# Functionality: Creates 6 production levels based on quantiles
# ============================================================================
print("\nBLOCK 3: Creating Quantile-Based Labels (6 Classes)")
print("=" * 50)

# Calculate quantiles from training data for 6 classes
production_col = 'Production (M.Ton)'
quantiles = train_df[production_col].quantile([0.1667, 0.3333, 0.5, 0.6667, 0.8333]).values

print(f"Quantile boundaries calculated for 6 classes:")
print(f"  Very Low: ≤ {quantiles[0]:.3f}")
print(f"  Low: {quantiles[0]:.3f} - {quantiles[1]:.3f}")
print(f"  Medium: {quantiles[1]:.3f} - {quantiles[2]:.3f}")
print(f"  High: {quantiles[2]:.3f} - {quantiles[3]:.3f}")
print(f"  Very High: {quantiles[3]:.3f} - {quantiles[4]:.3f}")
print(f"  Extremely High: > {quantiles[4]:.3f}")

def assign_labels(production_values):
    labels = []
    for val in production_values:
        if val <= quantiles[0]:
            labels.append(0)  # Very Low
        elif val <= quantiles[1]:
            labels.append(1)  # Low
        elif val <= quantiles[2]:
            labels.append(2)  # Medium
        elif val <= quantiles[3]:
            labels.append(3)  # High
        elif val <= quantiles[4]:
            labels.append(4)  # Very High
        else:
            labels.append(5)  # Extremely High
    return np.array(labels)

# Create labels for all datasets
train_labels = assign_labels(train_df[production_col].values)
val_labels = assign_labels(val_df[production_col].values)
test_labels = assign_labels(test_df[production_col].values)

# Add labels to dataframes
train_df['Production_Label'] = train_labels
val_df['Production_Label'] = val_labels
test_df['Production_Label'] = test_labels

label_names = ['Very Low', 'Low', 'Medium', 'High', 'Very High', 'Extremely High']
print(f"\n✓ Labels created successfully:")
for i, name in enumerate(label_names):
    count = np.sum(train_labels == i)
    print(f"  {name}: {count} samples ({count/len(train_labels)*100:.1f}%)")
# Out:
# BLOCK 3: Creating Quantile-Based Labels (6 Classes)
# ==================================================
# Quantile boundaries calculated for 6 classes:
#   Very Low: ≤ 417.000
#   Low: 417.000 - 996.507
#   Medium: 996.507 - 2027.000
#   High: 2027.000 - 3717.493
#   Very High: 3717.493 - 7522.298
#   Extremely High: > 7522.298
#
# ✓ Labels created successfully:
#   Very Low: 824 samples (16.7%)
#   Low: 819 samples (16.6%)
#   Medium: 821 samples (16.7%)
#   High: 821 samples (16.7%)
#   Very High: 821 samples (16.7%)
#   Extremely High: 822 samples (16.7%)

# %%
# ============================================================================
# BLOCK 4: PREPROCESS FEATURES
# Functionality: Scales numerical features and prepares data for model
# ============================================================================
print("\nBLOCK 4: Preprocessing Features")
print("=" * 50)

# Remove target columns
feature_cols = [col for col in train_df.columns if col not in ['Production (M.Ton)', 'Production_Label']]

# Identify feature types
numerical_features = []
categorical_features = []

for col in feature_cols:
    if train_df[col].dtype in ['int64', 'float64']:
        numerical_features.append(col)
    else:
        categorical_features.append(col)

one_hot_features = [col for col in feature_cols if col.startswith(('Crop_', 'District_'))]

print(f"✓ Feature analysis completed:")
print(f"  Total features: {len(feature_cols)}")
print(f"  Numerical features: {len(numerical_features)}")
print(f"  One-hot encoded features: {len(one_hot_features)}")

# Prepare features
X_train = train_df[feature_cols].copy()
X_val = val_df[feature_cols].copy()
X_test = test_df[feature_cols].copy()

# Scale numerical features
scaler = StandardScaler()
if numerical_features:
    X_train[numerical_features] = scaler.fit_transform(X_train[numerical_features])
    X_val[numerical_features] = scaler.transform(X_val[numerical_features])
    X_test[numerical_features] = scaler.transform(X_test[numerical_features])

# Handle missing values
X_train = X_train.fillna(0)
X_val = X_val.fillna(0)
X_test = X_test.fillna(0)

# Get labels
y_train = train_df['Production_Label'].values
y_val = val_df['Production_Label'].values
y_test = test_df['Production_Label'].values

print(f"✓ Feature preprocessing completed:")
print(f"  Training features shape: {X_train.shape}")
print(f"  Validation features shape: {X_val.shape}")
print(f"  Test features shape: {X_test.shape}")
# Out:
# BLOCK 4: Preprocessing Features
# ==================================================
# ✓ Feature analysis completed:
#   Total features: 85
#   Numerical features: 85
#   One-hot encoded features: 74
# ✓ Feature preprocessing completed:
#   Training features shape: (4928, 85)
#   Validation features shape: (1056, 85)
#   Test features shape: (1056, 85)

# %%
# ============================================================================
# BLOCK 5: BUILD AUTOINT MODEL (MODIFIED FOR 6 CLASSES)
# Functionality: Constructs the AutoInt model architecture for 6 classes
# ============================================================================
print("\nBLOCK 5: Building AutoInt Model (6 Classes)")
print("=" * 50)

def build_autoint_model(input_dim, embed_dim=64, num_heads=8, num_layers=3):
    # Input layer
    inputs = Input(shape=(input_dim,), name='feature_input')

    # Embedding layer for all features
    embedded = Dense(embed_dim, activation='relu', name='embedding')(inputs)
    embedded = Dropout(0.2)(embedded)

    # Reshape for attention mechanism using Keras Reshape layer
    from tensorflow.keras.layers import Reshape
    embedded_reshaped = Reshape((1, embed_dim))(embedded)

    # Stack AutoInt layers
    x = embedded_reshaped
    for i in range(num_layers):
        x = AutoIntLayer(embed_dim, num_heads, name=f'autoint_layer_{i}')(x)
        x = Dropout(0.1)(x)

    # Flatten the output
    x = Flatten()(x)

    # Dense layers for classification
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.1)(x)

    # Output layer (6 classes for production levels)
    outputs = Dense(6, activation='softmax', name='output')(x)

    # Create model
    model = Model(inputs=inputs, outputs=outputs)

    # Compile model
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# Build the model
model = build_autoint_model(X_train.shape[1])

print(f"✓ AutoInt model built successfully:")
print(f"  Total parameters: {model.count_params():,}")
print(f"  Input dimension: {X_train.shape[1]}")
print(f"  Output classes: 6")
print(f"  Embedding dimension: 64")
print(f"  Attention heads: 8")
print(f"  AutoInt layers: 3")
# Out:
# BLOCK 5: Building AutoInt Model (6 Classes)
# ==================================================
# ✓ AutoInt model built successfully:
#   Total parameters: 113,990
#   Input dimension: 85
#   Output classes: 6
#   Embedding dimension: 64
#   Attention heads: 8
#   AutoInt layers: 3

# %%
# ============================================================================
# BLOCK 6: TRAIN THE MODEL
# Functionality: Trains the model with early stopping and learning rate reduction
# ============================================================================
print("\nBLOCK 6: Training the Model")
print("=" * 50)

# Callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=10,
    min_lr=1e-6,
    verbose=1
)

print("✓ Training callbacks configured:")
print("  - Early stopping (patience=15)")
print("  - Learning rate reduction (factor=0.5)")

# Train model
print("\nStarting model training...")
history = model.fit(
    X_train.values, y_train,
    validation_data=(X_val.values, y_val),
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

print("✓ Model training completed successfully!")
print(f"  Training epochs: {len(history.history['accuracy'])}")
print(f"  Final training accuracy: {history.history['accuracy'][-1]:.4f}")
print(f"  Final validation accuracy: {history.history['val_accuracy'][-1]:.4f}")
# Out:
# BLOCK 6: Training the Model
# ==================================================
# ✓ Training callbacks configured:
#   - Early stopping (patience=15)
#   - Learning rate reduction (factor=0.5)
#
# Starting model training...
# Epoch 1/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.2000 - loss: 1.8125 - val_accuracy: 0.4422 - val_loss: 1.4351 - learning_rate: 0.0010
# Epoch 2/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3624 - loss: 1.5024 - val_accuracy: 0.4972 - val_loss: 1.2037 - learning_rate: 0.0010
# Epoch 3/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4359 - loss: 1.3383 - val_accuracy: 0.5710 - val_loss: 1.0944 - learning_rate: 0.0010
# Epoch 4/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.4917 - loss: 1.2234 - val_accuracy: 0.5814 - val_loss: 1.0263 - learning_rate: 0.0010
# Epoch 5/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5467 - loss: 1.1388 - val_accuracy: 0.5928 - val_loss: 0.9776 - learning_rate: 0.0010
# Epoch 6/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5501 - loss: 1.1068 - val_accuracy: 0.6042 - val_loss: 0.9545 - learning_rate: 0.0010
# Epoch 7/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5716 - loss: 1.0722 - val_accuracy: 0.6402 - val_loss: 0.9089 - learning_rate: 0.0010
# Epoch 8/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.5710 - loss: 1.0457 - val_accuracy: 0.6468 - val_loss: 0.8622 - learning_rate: 0.0010
# Epoch 9/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6095 - loss: 0.9789 - val_accuracy: 0.6780 - val_loss: 0.8398 - learning_rate: 0.0010
# Epoch 10/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6204 - loss: 0.9201 - val_accuracy: 0.6742 - val_loss: 0.8091 - learning_rate: 0.0010
# Epoch 11/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.6344 - loss: 0.9192 - val_accuracy: 0.7045 - val_loss: 0.7653 - learning_rate: 0.0010
# Epoch 12/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.6343 - loss: 0.9066 - val_accuracy: 0.7131 - val_loss: 0.7442 - learning_rate: 0.0010
# Epoch 13/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6618 - loss: 0.8618 - val_accuracy: 0.7273 - val_loss: 0.7181 - learning_rate: 0.0010
# Epoch 14/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6784 - loss: 0.8136 - val_accuracy: 0.7367 - val_loss: 0.7159 - learning_rate: 0.0010
# Epoch 15/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6742 - loss: 0.8221 - val_accuracy: 0.7396 - val_loss: 0.6783 - learning_rate: 0.0010
# Epoch 16/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6818 - loss: 0.8131 - val_accuracy: 0.7263 - val_loss: 0.6716 - learning_rate: 0.0010
# Epoch 17/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6891 - loss: 0.7843 - val_accuracy: 0.7443 - val_loss: 0.6415 - learning_rate: 0.0010
# Epoch 18/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7059 - loss: 0.7484 - val_accuracy: 0.7358 - val_loss: 0.6605 - learning_rate: 0.0010
# Epoch 19/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.7018 - loss: 0.7609 - val_accuracy: 0.7557 - val_loss: 0.6130 - learning_rate: 0.0010
# Epoch 20/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7260 - loss: 0.7190 - val_accuracy: 0.7642 - val_loss: 0.6158 - learning_rate: 0.0010
# Epoch 21/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7277 - loss: 0.6915 - val_accuracy: 0.7595 - val_loss: 0.6414 - learning_rate: 0.0010
# Epoch 22/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7236 - loss: 0.7214 - val_accuracy: 0.7689 - val_loss: 0.6134 - learning_rate: 0.0010
# Epoch 23/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7241 - loss: 0.7016 - val_accuracy: 0.7509 - val_loss: 0.6220 - learning_rate: 0.0010
# Epoch 24/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7361 - loss: 0.6758 - val_accuracy: 0.7680 - val_loss: 0.5870 - learning_rate: 0.0010
# Epoch 25/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7422 - loss: 0.6582 - val_accuracy: 0.7727 - val_loss: 0.5861 - learning_rate: 0.0010
# Epoch 26/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7460 - loss: 0.6480 - val_accuracy: 0.7926 - val_loss: 0.5554 - learning_rate: 0.0010
# Epoch 27/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7406 - loss: 0.6451 - val_accuracy: 0.7841 - val_loss: 0.5939 - learning_rate: 0.0010
# Epoch 28/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7449 - loss: 0.6482 - val_accuracy: 0.7718 - val_loss: 0.5893 - learning_rate: 0.0010
# Epoch 29/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7545 - loss: 0.6207 - val_accuracy: 0.7973 - val_loss: 0.5457 - learning_rate: 0.0010
# Epoch 30/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7739 - loss: 0.6127 - val_accuracy: 0.7822 - val_loss: 0.5706 - learning_rate: 0.0010
# Epoch 31/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7590 - loss: 0.6158 - val_accuracy: 0.7973 - val_loss: 0.5388 - learning_rate: 0.0010
# Epoch 32/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7720 - loss: 0.5917 - val_accuracy: 0.7964 - val_loss: 0.5483 - learning_rate: 0.0010
# Epoch 33/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.7721 - loss: 0.5833 - val_accuracy: 0.7869 - val_loss: 0.5447 - learning_rate: 0.0010
# Epoch 34/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.7707 - loss: 0.5776 - val_accuracy: 0.7945 - val_loss: 0.5366 - learning_rate: 0.0010
# Epoch 35/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.7592 - loss: 0.5937 - val_accuracy: 0.8049 - val_loss: 0.5290 - learning_rate: 0.0010
# Epoch 36/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7740 - loss: 0.5798 - val_accuracy: 0.7945 - val_loss: 0.5381 - learning_rate: 0.0010
# Epoch 37/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7752 - loss: 0.5782 - val_accuracy: 0.8002 - val_loss: 0.5333 - learning_rate: 0.0010
# Epoch 38/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7799 - loss: 0.5829 - val_accuracy: 0.8002 - val_loss: 0.5189 - learning_rate: 0.0010
# Epoch 39/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7926 - loss: 0.5494 - val_accuracy: 0.8097 - val_loss: 0.5053 - learning_rate: 0.0010
# Epoch 40/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7911 - loss: 0.5444 - val_accuracy: 0.8078 - val_loss: 0.5096 - learning_rate: 0.0010
# Epoch 41/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7790 - loss: 0.5651 - val_accuracy: 0.8002 - val_loss: 0.5209 - learning_rate: 0.0010
# Epoch 42/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7907 - loss: 0.5550 - val_accuracy: 0.8087 - val_loss: 0.5187 - learning_rate: 0.0010
# Epoch 43/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7822 - loss: 0.5501 - val_accuracy: 0.8144 - val_loss: 0.4916 - learning_rate: 0.0010
# Epoch 44/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8072 - loss: 0.5176 - val_accuracy: 0.8248 - val_loss: 0.4942 - learning_rate: 0.0010
# Epoch 45/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7823 - loss: 0.5469 - val_accuracy: 0.8116 - val_loss: 0.4983 - learning_rate: 0.0010
# Epoch 46/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.7902 - loss: 0.5390 - val_accuracy: 0.8116 - val_loss: 0.4968 - learning_rate: 0.0010
# Epoch 47/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8019 - loss: 0.5136 - val_accuracy: 0.8258 - val_loss: 0.4902 - learning_rate: 0.0010
# Epoch 48/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8037 - loss: 0.5176 - val_accuracy: 0.8295 - val_loss: 0.4894 - learning_rate: 0.0010
# Epoch 49/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7927 - loss: 0.5348 - val_accuracy: 0.8277 - val_loss: 0.4835 - learning_rate: 0.0010
# Epoch 50/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8120 - loss: 0.4898 - val_accuracy: 0.8163 - val_loss: 0.4927 - learning_rate: 0.0010
# Epoch 51/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8039 - loss: 0.4981 - val_accuracy: 0.8333 - val_loss: 0.4655 - learning_rate: 0.0010
# Epoch 52/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7996 - loss: 0.5278 - val_accuracy: 0.8125 - val_loss: 0.4938 - learning_rate: 0.0010
# Epoch 53/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8010 - loss: 0.5126 - val_accuracy: 0.8087 - val_loss: 0.5092 - learning_rate: 0.0010
# Epoch 54/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8181 - loss: 0.4848 - val_accuracy: 0.8277 - val_loss: 0.4866 - learning_rate: 0.0010
# Epoch 55/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8131 - loss: 0.4965 - val_accuracy: 0.8324 - val_loss: 0.4633 - learning_rate: 0.0010
# Epoch 56/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8203 - loss: 0.4934 - val_accuracy: 0.8191 - val_loss: 0.4736 - learning_rate: 0.0010
# Epoch 57/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8202 - loss: 0.4852 - val_accuracy: 0.8239 - val_loss: 0.5045 - learning_rate: 0.0010
# Epoch 58/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8171 - loss: 0.4897 - val_accuracy: 0.8210 - val_loss: 0.4814 - learning_rate: 0.0010
# Epoch 59/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8077 - loss: 0.4937 - val_accuracy: 0.8324 - val_loss: 0.4578 - learning_rate: 0.0010
# Epoch 60/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8223 - loss: 0.4724 - val_accuracy: 0.8172 - val_loss: 0.4901 - learning_rate: 0.0010
# Epoch 61/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8178 - loss: 0.4796 - val_accuracy: 0.8201 - val_loss: 0.4814 - learning_rate: 0.0010
# Epoch 62/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8225 - loss: 0.4637 - val_accuracy: 0.8333 - val_loss: 0.4635 - learning_rate: 0.0010
# Epoch 63/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8096 - loss: 0.4851 - val_accuracy: 0.8248 - val_loss: 0.4706 - learning_rate: 0.0010
# Epoch 64/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8161 - loss: 0.4918 - val_accuracy: 0.8106 - val_loss: 0.4994 - learning_rate: 0.0010
# Epoch 65/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8161 - loss: 0.4728 - val_accuracy: 0.8248 - val_loss: 0.4745 - learning_rate: 0.0010
# Epoch 66/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8119 - loss: 0.4673 - val_accuracy: 0.8201 - val_loss: 0.4676 - learning_rate: 0.0010
# Epoch 67/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8289 - loss: 0.4518 - val_accuracy: 0.8295 - val_loss: 0.4672 - learning_rate: 0.0010
# Epoch 68/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8271 - loss: 0.4500 - val_accuracy: 0.8295 - val_loss: 0.4487 - learning_rate: 0.0010
# Epoch 69/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8268 - loss: 0.4486 - val_accuracy: 0.8134 - val_loss: 0.4698 - learning_rate: 0.0010
# Epoch 70/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8224 - loss: 0.4460 - val_accuracy: 0.8343 - val_loss: 0.4658 - learning_rate: 0.0010
# Epoch 71/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8187 - loss: 0.4783 - val_accuracy: 0.8352 - val_loss: 0.4773 - learning_rate: 0.0010
# Epoch 72/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8240 - loss: 0.4512 - val_accuracy: 0.8305 - val_loss: 0.4650 - learning_rate: 0.0010
# Epoch 73/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8391 - loss: 0.4364 - val_accuracy: 0.8295 - val_loss: 0.4672 - learning_rate: 0.0010
# Epoch 74/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8278 - loss: 0.4444 - val_accuracy: 0.8295 - val_loss: 0.4545 - learning_rate: 0.0010
# Epoch 75/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8296 - loss: 0.4509 - val_accuracy: 0.8324 - val_loss: 0.4456 - learning_rate: 0.0010
# Epoch 76/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8280 - loss: 0.4397 - val_accuracy: 0.8248 - val_loss: 0.4551 - learning_rate: 0.0010
# Epoch 77/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8266 - loss: 0.4641 - val_accuracy: 0.8352 - val_loss: 0.4504 - learning_rate: 0.0010
# Epoch 78/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8342 - loss: 0.4352 - val_accuracy: 0.8258 - val_loss: 0.4476 - learning_rate: 0.0010
# Epoch 79/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8302 - loss: 0.4586 - val_accuracy: 0.8343 - val_loss: 0.4480 - learning_rate: 0.0010
# Epoch 80/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8398 - loss: 0.4303 - val_accuracy: 0.8286 - val_loss: 0.4513 - learning_rate: 0.0010
# Epoch 81/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.8413 - loss: 0.4363 - val_accuracy: 0.8324 - val_loss: 0.4330 - learning_rate: 0.0010
# Epoch 82/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8386 - loss: 0.4297 - val_accuracy: 0.8371 - val_loss: 0.4268 - learning_rate: 0.0010
# Epoch 83/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8287 - loss: 0.4186 - val_accuracy: 0.8314 - val_loss: 0.4420 - learning_rate: 0.0010
# Epoch 84/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8337 - loss: 0.4321 - val_accuracy: 0.8277 - val_loss: 0.4466 - learning_rate: 0.0010
# Epoch 85/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8448 - loss: 0.4136 - val_accuracy: 0.8447 - val_loss: 0.4467 - learning_rate: 0.0010
# Epoch 86/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8494 - loss: 0.4112 - val_accuracy: 0.8362 - val_loss: 0.4378 - learning_rate: 0.0010
# Epoch 87/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8302 - loss: 0.4316 - val_accuracy: 0.8343 - val_loss: 0.4647 - learning_rate: 0.0010
# Epoch 88/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8516 - loss: 0.4101 - val_accuracy: 0.8295 - val_loss: 0.4470 - learning_rate: 0.0010
# Epoch 89/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.8332 - loss: 0.4368 - val_accuracy: 0.8371 - val_loss: 0.4839 - learning_rate: 0.0010
# Epoch 90/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8432 - loss: 0.4284 - val_accuracy: 0.8352 - val_loss: 0.4469 - learning_rate: 0.0010
# Epoch 91/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8463 - loss: 0.4073 - val_accuracy: 0.8419 - val_loss: 0.4276 - learning_rate: 0.0010
# Epoch 92/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8360 - loss: 0.4302
# Epoch 92: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8359 - loss: 0.4302 - val_accuracy: 0.8305 - val_loss: 0.4399 - learning_rate: 0.0010
# Epoch 93/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8468 - loss: 0.3909 - val_accuracy: 0.8523 - val_loss: 0.4345 - learning_rate: 5.0000e-04
# Epoch 94/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8518 - loss: 0.3776 - val_accuracy: 0.8409 - val_loss: 0.4362 - learning_rate: 5.0000e-04
# Epoch 95/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8503 - loss: 0.3716 - val_accuracy: 0.8447 - val_loss: 0.4234 - learning_rate: 5.0000e-04
# Epoch 96/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8593 - loss: 0.3538 - val_accuracy: 0.8390 - val_loss: 0.4251 - learning_rate: 5.0000e-04
# Epoch 97/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8571 - loss: 0.3688 - val_accuracy: 0.8419 - val_loss: 0.4416 - learning_rate: 5.0000e-04
# Epoch 98/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8614 - loss: 0.3726 - val_accuracy: 0.8371 - val_loss: 0.4246 - learning_rate: 5.0000e-04
# Epoch 99/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8667 - loss: 0.3616 - val_accuracy: 0.8494 - val_loss: 0.4280 - learning_rate: 5.0000e-04
# Epoch 100/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8600 - loss: 0.3608 - val_accuracy: 0.8352 - val_loss: 0.4411 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 95.
# ✓ Model training completed successfully!
#   Training epochs: 100
#   Final training accuracy: 0.8618
#   Final validation accuracy: 0.8352

# %%
# ============================================================================
# BLOCK 7: CALCULATE CLASSIFICATION METRICS FUNCTION
# Functionality: Defines function to calculate all required metrics
# ============================================================================
print("\nBLOCK 7: Classification Metrics Function")
print("=" * 50)

def calculate_metrics(y_true, y_pred, label_names):
    """Calculate comprehensive classification metrics"""
    # Basic metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision_macro = precision_score(y_true, y_pred, average='macro')
    recall_macro = recall_score(y_true, y_pred, average='macro')
    f1_macro = f1_score(y_true, y_pred, average='macro')

    precision_weighted = precision_score(y_true, y_pred, average='weighted')
    recall_weighted = recall_score(y_true, y_pred, average='weighted')
    f1_weighted = f1_score(y_true, y_pred, average='weighted')

    # Print metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision (Macro): {precision_macro:.4f}")
    print(f"Recall (Macro): {recall_macro:.4f}")
    print(f"F1 Score (Macro): {f1_macro:.4f}")
    print(f"Precision (Weighted): {precision_weighted:.4f}")
    print(f"Recall (Weighted): {recall_weighted:.4f}")
    print(f"F1 Score (Weighted): {f1_weighted:.4f}")

    # Classification report
    print("\nDetailed Classification Report:")
    print(classification_report(y_true, y_pred, target_names=label_names))

    return {
        'accuracy': accuracy,
        'precision_macro': precision_macro,
        'recall_macro': recall_macro,
        'f1_macro': f1_macro,
        'precision_weighted': precision_weighted,
        'recall_weighted': recall_weighted,
        'f1_weighted': f1_weighted
    }

print("✓ Metrics calculation function ready")
print("✓ Will calculate: Accuracy, Precision, Recall, F1 scores")
print("✓ Both macro and weighted averages included")
# Out:
# BLOCK 7: Classification Metrics Function
# ==================================================
# ✓ Metrics calculation function ready
# ✓ Will calculate: Accuracy, Precision, Recall, F1 scores
# ✓ Both macro and weighted averages included

# %%
# ============================================================================
# BLOCK 8: PLOT CONFUSION MATRIX FUNCTION
# Functionality: Creates confusion matrix visualization
# ============================================================================
print("\nBLOCK 8: Confusion Matrix Plotting Function")
print("=" * 50)

def plot_confusion_matrix(y_true, y_pred, label_names, title="Confusion Matrix"):
    """Plot confusion matrix with proper formatting"""
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=label_names, yticklabels=label_names)
    plt.title(title, fontsize=14, fontweight='bold')
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

    return cm

print("✓ Confusion matrix plotting function ready")
print("✓ Will create heatmap visualization for 6 classes")
print("✓ Supports custom titles and labels")
# Out:
# BLOCK 8: Confusion Matrix Plotting Function
# ==================================================
# ✓ Confusion matrix plotting function ready
# ✓ Will create heatmap visualization for 6 classes
# ✓ Supports custom titles and labels

# %%
# ============================================================================
# BLOCK 9: PLOT TRAINING HISTORY
# Functionality: Visualizes training vs validation accuracy and loss
# ============================================================================
print("\nBLOCK 9: Training History Visualization")
print("=" * 50)

def plot_training_history(history, title="Training History"):
    """Plot training and validation accuracy/loss"""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Accuracy plot
    ax1.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    ax1.set_title('Model Accuracy', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Epoch', fontsize=12)
    ax1.set_ylabel('Accuracy', fontsize=12)
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # Loss plot
    ax2.plot(history.history['loss'], label='Training Loss', linewidth=2)
    ax2.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    ax2.set_title('Model Loss', fontsize=14, fontweight='bold')
    ax2.set_xlabel('Epoch', fontsize=12)
    ax2.set_ylabel('Loss', fontsize=12)
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# Execute training history plot
print("Plotting training history...")
plot_training_history(history)
print("✓ Training history plotted successfully")
# Out:
# BLOCK 9: Training History Visualization
# ==================================================
# Plotting training history...
# ✓ Training history plotted successfully

# %%
# ============================================================================
# BLOCK 10: EVALUATE VALIDATION SET
# Functionality: Evaluates model on validation set and shows all metrics
# ============================================================================
print("\nBLOCK 10: Validation Set Evaluation")
print("=" * 50)

# Get validation predictions
val_pred_probs = model.predict(X_val.values)
val_pred = np.argmax(val_pred_probs, axis=1)

print("Validation Set Results:")
print("-" * 30)
val_metrics = calculate_metrics(y_val, val_pred, label_names)

# Plot validation confusion matrix
plot_confusion_matrix(y_val, val_pred, label_names, "Validation Set Confusion Matrix")

print("✓ Validation evaluation completed")
print(f"  Validation Accuracy: {val_metrics['accuracy']:.4f}")
print(f"  Validation Macro F1: {val_metrics['f1_macro']:.4f}")
# Out:
# BLOCK 10: Validation Set Evaluation
# ==================================================
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Validation Set Results:
# ------------------------------
# Accuracy: 0.8447
# Precision (Macro): 0.8436
# Recall (Macro): 0.8436
# F1 Score (Macro): 0.8432
# Precision (Weighted): 0.8444
# Recall (Weighted): 0.8447
# F1 Score (Weighted): 0.8442
#
# Detailed Classification Report:
#                 precision    recall  f1-score   support
#
#       Very Low       0.91      0.94      0.92       188
#            Low       0.85      0.80      0.82       181
#         Medium       0.79      0.76      0.77       170
#           High       0.79      0.84      0.81       176
#      Very High       0.81      0.81      0.81       171
# Extremely High       0.91      0.92      0.92       170
#
#       accuracy                           0.84      1056
#      macro avg       0.84      0.84      0.84      1056
#   weighted avg       0.84      0.84      0.84      1056
# ✓ Validation evaluation completed
#   Validation Accuracy: 0.8447
#   Validation Macro F1: 0.8432

# %%
# ============================================================================
# BLOCK 11: EVALUATE TEST SET
# Functionality: Evaluates model on test set and shows all metrics
# ============================================================================
print("\nBLOCK 11: Test Set Evaluation")
print("=" * 50)

# Get test predictions
test_pred_probs = model.predict(X_test.values)
test_pred = np.argmax(test_pred_probs, axis=1)

print("Test Set Results:")
print("-" * 30)
test_metrics = calculate_metrics(y_test, test_pred, label_names)

# Plot test confusion matrix
plot_confusion_matrix(y_test, test_pred, label_names, "Test Set Confusion Matrix")

print("✓ Test evaluation completed")
print(f"  Test Accuracy: {test_metrics['accuracy']:.4f}")
print(f"  Test Macro F1: {test_metrics['f1_macro']:.4f}")
# Out:
# BLOCK 11: Test Set Evaluation
# ==================================================
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Test Set Results:
# ------------------------------
# Accuracy: 0.8125
# Precision (Macro): 0.8136
# Recall (Macro): 0.8132
# F1 Score (Macro): 0.8128
# Precision (Weighted): 0.8154
# Recall (Weighted): 0.8125
# F1 Score (Weighted): 0.8133
#
# Detailed Classification Report:
#                 precision    recall  f1-score   support
#
#       Very Low       0.95      0.91      0.93       190
#            Low       0.78      0.78      0.78       165
#         Medium       0.76      0.74      0.75       180
#           High       0.70      0.79      0.74       164
#      Very High       0.79      0.75      0.77       195
# Extremely High       0.90      0.91      0.90       162
#
#       accuracy                           0.81      1056
#      macro avg       0.81      0.81      0.81      1056
#   weighted avg       0.82      0.81      0.81      1056
# ✓ Test evaluation completed
#   Test Accuracy: 0.8125
#   Test Macro F1: 0.8128

# %%
# ============================================================================
# BLOCK 12: COMPARE VALIDATION VS TEST PERFORMANCE
# Functionality: Creates side-by-side comparison of validation and test metrics
# ============================================================================
print("\nBLOCK 12: Performance Comparison")
print("=" * 50)

metrics_names = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro',
                'precision_weighted', 'recall_weighted', 'f1_weighted']

val_values = [val_metrics[metric] for metric in metrics_names]
test_values = [test_metrics[metric] for metric in metrics_names]

# Create comparison plot
x = np.arange(len(metrics_names))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 8))
bars1 = ax.bar(x - width/2, val_values, width, label='Validation', alpha=0.8)
bars2 = ax.bar(x + width/2, test_values, width, label='Test', alpha=0.8)

ax.set_xlabel('Metrics', fontsize=12)
ax.set_ylabel('Score', fontsize=12)
ax.set_title('Validation vs Test Performance Comparison', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels([name.replace('_', ' ').title() for name in metrics_names], rotation=45)
ax.legend()
ax.grid(True, alpha=0.3)

# Add value labels on bars
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.3f}',
                   xy=(bar.get_x() + bar.get_width() / 2, height),
                   xytext=(0, 3),
                   textcoords="offset points",
                   ha='center', va='bottom', fontsize=9)

autolabel(bars1)
autolabel(bars2)

plt.tight_layout()
plt.show()

print("✓ Performance comparison completed")
# Out:
# BLOCK 12: Performance Comparison
# ==================================================
# ✓ Performance comparison completed

# %%
# ============================================================================
# BLOCK 13: FINAL SUMMARY AND RESULTS
# Functionality: Comprehensive summary of model performance
# ============================================================================
print("\nBLOCK 13: Final Summary and Results")
print("=" * 60)
print("AUTOINT MODEL PERFORMANCE SUMMARY (6 CLASSES)")
print("=" * 60)

print(f"Model Type: AutoInt with Self-Attention")
print(f"Task: Agricultural Production Classification")
print(f"Classes: {', '.join(label_names)}")
print(f"Classification Method: Quantile-based (~16.67% each class)")

print(f"\nDATASET INFORMATION:")
print(f"Training samples: {len(X_train)}")
print(f"Validation samples: {len(X_val)}")
print(f"Test samples: {len(X_test)}")
print(f"Total features: {X_train.shape[1]}")

print(f"\nVALIDATION SET RESULTS:")
print(f"Accuracy: {val_metrics['accuracy']:.4f}")
print(f"Macro F1 Score: {val_metrics['f1_macro']:.4f}")
print(f"Weighted F1 Score: {val_metrics['f1_weighted']:.4f}")
print(f"Precision (Macro): {val_metrics['precision_macro']:.4f}")
print(f"Recall (Macro): {val_metrics['recall_macro']:.4f}")

print(f"\nTEST SET RESULTS:")
print(f"Accuracy: {test_metrics['accuracy']:.4f}")
print(f"Macro F1 Score: {test_metrics['f1_macro']:.4f}")
print(f"Weighted F1 Score: {test_metrics['f1_weighted']:.4f}")
print(f"Precision (Macro): {test_metrics['precision_macro']:.4f}")
print(f"Recall (Macro): {test_metrics['recall_macro']:.4f}")

print(f"\nMODEL GENERALIZATION ANALYSIS:")
acc_diff = abs(val_metrics['accuracy'] - test_metrics['accuracy'])
f1_diff = abs(val_metrics['f1_macro'] - test_metrics['f1_macro'])
print(f"Accuracy Difference (Val vs Test): {acc_diff:.4f}")
print(f"Macro F1 Difference (Val vs Test): {f1_diff:.4f}")

if acc_diff < 0.05 and f1_diff < 0.05:
    print("✓ Model shows excellent generalization")
elif acc_diff < 0.10 and f1_diff < 0.10:
    print("✓ Model shows good generalization")
else:
    print("⚠ Model may have overfitting issues")

print(f"\nKEY ACHIEVEMENTS:")
print(f"✓ Successfully implemented AutoInt architecture")
print(f"✓ Modified for 6 production classes")
print(f"✓ Achieved {val_metrics['accuracy']:.1%} validation accuracy")
print(f"✓ Achieved {test_metrics['accuracy']:.1%} test accuracy")
print(f"✓ Macro F1 Score: {test_metrics['f1_macro']:.4f}")
print(f"✓ All classification metrics calculated")
print(f"✓ Confusion matrices generated")
print(f"✓ Training history visualized")

print("=" * 60)
print("EXECUTION COMPLETED SUCCESSFULLY!")
print("=" * 60)
# Out:
# BLOCK 13: Final Summary and Results
# ============================================================
# AUTOINT MODEL PERFORMANCE SUMMARY (6 CLASSES)
# ============================================================
# Model Type: AutoInt with Self-Attention
# Task: Agricultural Production Classification
# Classes: Very Low, Low, Medium, High, Very High, Extremely High
# Classification Method: Quantile-based (~16.67% each class)
#
# DATASET INFORMATION:
# Training samples: 4928
# Validation samples: 1056
# Test samples: 1056
# Total features: 85
#
# VALIDATION SET RESULTS:
# Accuracy: 0.8447
# Macro F1 Score: 0.8432
# Weighted F1 Score: 0.8442
# Precision (Macro): 0.8436
# Recall (Macro): 0.8436
#
# TEST SET RESULTS:
# Accuracy: 0.8125
# Macro F1 Score: 0.8128
# Weighted F1 Score: 0.8133
# Precision (Macro): 0.8136
# Recall (Macro): 0.8132
#
# MODEL GENERALIZATION ANALYSIS:
# Accuracy Difference (Val vs Test): 0.0322
# Macro F1 Difference (Val vs Test): 0.0304
# ✓ Model shows excellent generalization
#
# KEY ACHIEVEMENTS:
# ✓ Successfully implemented AutoInt architecture
# ✓ Modified for 6 production classes
# ✓ Achieved 84.5% validation accuracy
# ✓ Achieved 81.2% test accuracy
# ✓ Macro F1 Score: 0.8128
# ✓ All classification metrics calculated
# ✓ Confusion matrices generated
# ✓ Training history visualized
# ============================================================
# EXECUTION COMPLETED SUCCESSFULLY!
# ============================================================
